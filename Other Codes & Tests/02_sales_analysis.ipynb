# %%
import pandas as pd

sales = pd.read_csv("../data/sales_data.csv")

sales
# Out:
#          Date  Product     Category  Sales
# 0  2026-01-01   Laptop  Electronics   1200
# 1  2026-01-02    Phone  Electronics    800
# 2  2026-01-03     Desk    Furniture    450
# 3  2026-01-04    Chair    Furniture    300
# 4  2026-01-05  Monitor  Electronics    500

# %%
sales.describe()
# Out:
#              Sales
# count     5.000000
# mean    650.000000
# std     357.071421
# min     300.000000
# 25%     450.000000
# 50%     500.000000
# 75%     800.000000
# max    1200.000000

# %%
import matplotlib.pyplot as plt

sales.plot(
    x="Product",
    y="Sales",
    kind="bar",
    title="Sales by Product"
)

plt.show()
